# %%
# %cd genai-experiments
# Out:
# [Errno 2] No such file or directory: 'genai-experiments'
# /content

# %%
# !git add .

# %%
# !git config --global user.email "akashchauhan72520@gmail.com"

# %%
# !git config --global user.name "Ankit Chauhan"

# %%
# !git commit -m "Added my notebook"
# Out:
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !git status
# !git branch
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !echo "This is a test file." > test.txt
# !git add .
# !git commit -m "Add test file"
# !git push -u origin main
# Out:
# [main (root-commit) eee168a] Add test file
#  1 file changed, 1 insertion(+)
#  create mode 100644 test.txt
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 238 bytes | 238.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/chauhan-ankit24/genai-experiments.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git branch data-preprocessing-cleaning

# %%
# !git checkout data-preprocessing-cleaning
# Out:
# Switched to branch 'data-preprocessing-cleaning'

# %%
# !git status
# Out:
# On branch data-preprocessing-cleaning
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m 'added readme'
# Out:
# [data-preprocessing-cleaning 7e1129f] added readme
#  1 file changed, 9 insertions(+)
#  create mode 100644 README.md

# %%
# !git push origin data-preprocessing-cleaning
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 466 bytes | 466.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'data-preprocessing-cleaning' on GitHub by visiting:
# remote:      https://github.com/chauhan-ankit24/genai-experiments/pull/new/data-preprocessing-cleaning
# remote:
# To https://github.com/chauhan-ankit24/genai-experiments.git
#  * [new branch]      data-preprocessing-cleaning -> data-preprocessing-cleaning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://chauhan-ankit24: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git@github.com:chauhan-ankit24/genai-experiments.git
# Out:
# Cloning into 'genai-experiments'...
# fatal: unable to access 'https://github.com:chauhan-ankit24/genai-experiments.git/': URL using bad/illegal format or missing URL

# %%
# !git clone https://chauhan-ankit24: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git@github.com/chauhan-ankit24/genai-experiments.git
# Out:
# Cloning into 'genai-experiments'...
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/chauhan-ankit24/genai-experiments.git/'

# %%
# !git clone https://chauhan-ankit24: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@github.com/chauhan-ankit24/genai-experiments.git
# Out:
# Cloning into 'genai-experiments'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.

# %%
# %cd /content/drive/MyDrive/genai-experiments
# Out:
# /content/drive/MyDrive/genai-experiments

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git checkout data-preprocessing-cleaning
# Out:
# Branch 'data-preprocessing-cleaning' set up to track remote branch 'data-preprocessing-cleaning' from 'origin'.
# Switched to a new branch 'data-preprocessing-cleaning'

# %%
import pandas as pd

# %%
data_path = '/content/drive/MyDrive/genai-experiments/data/IMDB Dataset.csv'

# %%
df= pd.read_csv(data_path)

# %%
df.shape
# Out:
# (50000, 2)

# %%
df = df.head(100)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.shape
# Out:
# (100, 2)

# %% [markdown]
# # lower case operation

# %%
df['review'][3]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
df['review'] = df['review'].str.lower()

# %% [markdown]
# # remove_html_tags

# %%
import re
def remove_html_tags(text):
  pattern = re.compile('<.*?>')
  return pattern.sub(r'', text)

df['review'] = df['review'].apply(remove_html_tags)
df['review'][3]
# Out:
# "basically there's a family where a little boy (jake) thinks there's a zombie in his closet & his parents are fighting all the time.this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie.ok, first of all when you're going to make a film you must decide if its a thriller or a drama! as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film! i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake: just ignore them."

# %% [markdown]
# # remove_url

# %%
def remove_url(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'', text)

df['review'] = df['review'].apply(remove_url)
df['review'][3]
# Out:
# "basically there's a family where a little boy (jake) thinks there's a zombie in his closet & his parents are fighting all the time.this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie.ok, first of all when you're going to make a film you must decide if its a thriller or a drama! as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film! i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots.3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake: just ignore them."

# %% [markdown]
# # puntuation handling

# %%
import string
def remove_punctuation(text):
  exclude = string.punctuation
  return ''.join(char for char in text if char not in exclude)

df['review'] = df['review'].apply(remove_punctuation)
df['review'][3]
# Out:
# 'basically theres a family where a little boy jake thinks theres a zombie in his closet  his parents are fighting all the timethis movie is slower than a soap opera and suddenly jake decides to become rambo and kill the zombieok first of all when youre going to make a film you must decide if its a thriller or a drama as a drama the movie is watchable parents are divorcing  arguing like in real life and then we have jake with his closet which totally ruins all the film i expected to see a boogeyman similar movie and instead i watched a drama with some meaningless thriller spots3 out of 10 just for the well playing parents  descent dialogs as for the shots with jake just ignore them'

# %% [markdown]
# # Chat_converstaion

# %%
text_shortcuts = {
    'LOL': 'laughing out loud',
    'BRB': 'be right back',
    'TTYL': 'talk to you later',
    'IMO': 'in my opinion',
    'IDK': 'I don\'t know'
}

def expand_shortcuts(text):
  words = text.split()
  expanded_words = []
  for word in words:
    if word in text_shortcuts:
      expanded_words.append(text_shortcuts[word])
    else:
      expanded_words.append(word)
  return ' '.join(expanded_words)

sample_text = "This is a test. LOL BRB TTYL IMO IDK."
print(expand_shortcuts(sample_text))
# Out:
# This is a test. laughing out loud be right back talk to you later in my opinion IDK.

# %% [markdown]
# # Incorrect_text_handling

# %%
# !pip install pyspellchecker

from spellchecker import SpellChecker

spell = SpellChecker()

def correct_spellings(text):
  corrected_text = []
  for word in text.split():
    corrected_text.append(spell.correction(word))
  return " ".join(corrected_text)

sample_text_misspelled = "Thiss is a tessst sentence with sum misspeld wurds."
corrected_text = correct_spellings(sample_text_misspelled)
print(f"Original: {sample_text_misspelled}")
print(f"Corrected: {corrected_text}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 31.8 MB/s eta 0:00:00
# ...
# Original: Thiss is a tessst sentence with sum misspeld wurds.
# Corrected: this is a test sentence with sum misspell words

# %% [markdown]
# # stop_words

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

def remove_stopwords(text):
  new_text = []
  for word in text.split():
    if word not in stopwords.words('english'):
      new_text.append(word)
  return " ".join(new_text)

df['review'] = df['review'].apply(remove_stopwords)
df['review'][3]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 'basically theres family little boy jake thinks theres zombie closet parents fighting timethis movie slower soap opera suddenly jake decides become rambo kill zombieok first youre going make film must decide thriller drama drama movie watchable parents divorcing arguing like real life jake closet totally ruins film expected see boogeyman similar movie instead watched drama meaningless thriller spots3 10 well playing parents descent dialogs shots jake ignore'

# %% [markdown]
# # remove_emoji

# %%
def remove_emoji(text):
  emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
  return emoji_pattern.sub(r'', text)

df['review'] = df['review'].apply(remove_emoji)
df['review'][3]
# Out:
# 'basically theres family little boy jake thinks theres zombie closet parents fighting timethis movie slower soap opera suddenly jake decides become rambo kill zombieok first youre going make film must decide thriller drama drama movie watchable parents divorcing arguing like real life jake closet totally ruins film expected see boogeyman similar movie instead watched drama meaningless thriller spots3 10 well playing parents descent dialogs shots jake ignore'

# %% [markdown]
# # Emoji_to_text

# %%
# !pip install emoji

import emoji

def convert_emoji_to_text(text):
  return emoji.demojize(text, delimiters=(" ", " "))

sample_text_with_emoji = "This is a test with emojis 😂👍."
converted_text = convert_emoji_to_text(sample_text_with_emoji)
print(f"Original: {sample_text_with_emoji}")
print(f"Converted: {converted_text}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 7.8 MB/s eta 0:00:00
# ...
# Original: This is a test with emojis 😂👍.
# Converted: This is a test with emojis  face_with_tears_of_joy  thumbs_up .

# %%
# %cd /content/drive/MyDrive/genai-experiments

# %%
# !git status
# Out:
# On branch data-preprocessing-cleaning
# Your branch is up to date with 'origin/data-preprocessing-cleaning'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Colab Notebooks/
# 	data/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .
# !git commit -m "cleanUp Done"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@5661065eb8c6.(none)')

# %%
git config --global user.email

# %%
# Out:
# /content/drive/MyDrive/genai-experiments
